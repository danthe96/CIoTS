# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from CIoTS import *

# %%
generator = CausalTSGenerator(dimensions=3, max_p=5, incoming_edges=4)
data = generator.generate()

# %%
generator.draw_graph()

# %%
transformed = transform_ts(data, generator.max_p)
labels = list(transformed[0].values())

pd.DataFrame(np.corrcoef(transformed[1], rowvar=False), columns=labels, index=labels)
# Out:
#             X0_t      X1_t      X2_t    X0_t-1    X1_t-1    X2_t-1    X0_t-2  \
# X0_t    1.000000  0.254793  0.009583 -0.310320 -0.212839  0.087533  0.521281
# X1_t    0.254793  1.000000 -0.008456 -0.544991 -0.216164 -0.122317  0.222964
# X2_t    0.009583 -0.008456  1.000000  0.051087 -0.122394 -0.903323  0.016248
# X0_t-1 -0.310320 -0.544991  0.051087  1.000000  0.258592  0.010379 -0.312037
# X1_t-1 -0.212839 -0.216164 -0.122394  0.258592  1.000000 -0.010625 -0.543485
# X2_t-1  0.087533 -0.122317 -0.903323  0.010379 -0.010625  1.000000  0.052276
# X0_t-2  0.521281  0.222964  0.016248 -0.312037 -0.543485  0.052276  1.000000
# X1_t-2  0.108522  0.470945  0.088226 -0.213664 -0.214102 -0.121742  0.257693
# X2_t-2  0.012714  0.040218  0.885430  0.086573 -0.120175 -0.903254  0.008994
# X0_t-3 -0.055020 -0.811614  0.119016  0.521164  0.223656  0.016381 -0.312523
# X1_t-3  0.227162 -0.303741 -0.143236  0.111044  0.467514  0.086598 -0.211292
# X2_t-3 -0.048474 -0.066043 -0.901003  0.012621  0.040338  0.885766  0.086588
# X0_t-4 -0.005313  0.092942  0.037381 -0.057778 -0.810161  0.121524  0.519847
# X1_t-4 -0.067883  0.213415  0.223009  0.226132 -0.301793 -0.142369  0.109538
# X2_t-4  0.003063 -0.019808  0.965806 -0.049493 -0.063958 -0.900921  0.011347
# X0_t-5  0.211770 -0.336667 -0.012214 -0.004863  0.091690  0.036960 -0.057110
# X1_t-5  0.676381 -0.157950 -0.151300 -0.066783  0.210794  0.222219  0.228255
# X2_t-5 -0.070310 -0.079642 -0.901383  0.003760 -0.021909  0.965785 -0.048519
#
#           X1_t-2    X2_t-2    X0_t-3    X1_t-3    X2_t-3    X0_t-4    X1_t-4  \
# X0_t    0.108522  0.012714 -0.055020  0.227162 -0.048474 -0.005313 -0.067883
# X1_t    0.470945  0.040218 -0.811614 -0.303741 -0.066043  0.092942  0.213415
# X2_t    0.088226  0.885430  0.119016 -0.143236 -0.901003  0.037381  0.223009
# X0_t-1 -0.213664  0.086573  0.521164  0.111044  0.012621 -0.057778  0.226132
# X1_t-1 -0.214102 -0.120175  0.223656  0.467514  0.040338 -0.810161 -0.301793
# X2_t-1 -0.121742 -0.903254  0.016381  0.086598  0.885766  0.121524 -0.142369
# X0_t-2  0.257693  0.008994 -0.312523 -0.211292  0.086588  0.519847  0.109538
# X1_t-2  1.000000 -0.011592 -0.543894 -0.212693 -0.120298  0.222071  0.466838
# X2_t-2 -0.011592  1.000000  0.052176 -0.119768 -0.903758  0.013869  0.085454
# X0_t-3 -0.543894  0.052176  1.000000  0.258722  0.009019 -0.313816 -0.211580
# X1_t-3 -0.212693 -0.119768  0.258722  1.000000 -0.011508 -0.541229 -0.210558
# X2_t-3 -0.120298 -0.903758  0.009019 -0.011508  1.000000  0.052248 -0.119898
# X0_t-4  0.222071  0.013869 -0.313816 -0.541229  0.052248  1.000000  0.256639
# X1_t-4  0.466838  0.085454 -0.211580 -0.210558 -0.119898  0.256639  1.000000
# X2_t-4  0.039465  0.885659  0.086522 -0.118490 -0.904179  0.006689 -0.012671
# X0_t-5 -0.810107  0.122164  0.520020  0.221464  0.013910 -0.313468 -0.541024
# X1_t-5 -0.301034 -0.141246  0.109842  0.465532  0.085593 -0.209183 -0.209294
# X2_t-5 -0.063348 -0.900862  0.011487  0.037844  0.885951  0.088759 -0.117660
#
#           X2_t-4    X0_t-5    X1_t-5    X2_t-5
# X0_t    0.003063  0.211770  0.676381 -0.070310
# X1_t   -0.019808 -0.336667 -0.157950 -0.079642
# X2_t    0.965806 -0.012214 -0.151300 -0.901383
# X0_t-1 -0.049493 -0.004863 -0.066783  0.003760
# X1_t-1 -0.063958  0.091690  0.210794 -0.021909
# X2_t-1 -0.900921  0.036960  0.222219  0.965785
# X0_t-2  0.011347 -0.057110  0.228255 -0.048519
# X1_t-2  0.039465 -0.810107 -0.301034 -0.063348
# X2_t-2  0.885659  0.122164 -0.141246 -0.900862
# X0_t-3  0.086522  0.520020  0.109842  0.011487
# X1_t-3 -0.118490  0.221464  0.465532  0.037844
# X2_t-3 -0.904179  0.013910  0.085593  0.885951
# X0_t-4  0.006689 -0.313468 -0.209183  0.088759
# X1_t-4 -0.012671 -0.541024 -0.209294 -0.117660
# X2_t-4  1.000000  0.052802 -0.118832 -0.904104
# X0_t-5  0.052802  1.000000  0.256214  0.006297
# X1_t-5 -0.118832  0.256214  1.000000 -0.013638
# X2_t-5 -0.904104  0.006297 -0.013638  1.000000

# %%
for col in data.columns:
    plt.plot(np.arange(len(data)), data[col])
    plt.show()

# %%
from statsmodels.tsa.vector_ar import util

A_var1 = util.comp_matrix(generator.VAR_exog)
eigs = np.linalg.eigvals(A_var1)
np.abs(eigs)
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.98064645, 0.98064645, 1.28391793, 1.28391793, 0.94664212,
#        0.86761355, 0.86761355, 0.81989164, 0.81989164, 0.31207109])

# %%
from statsmodels.tsa.vector_ar.var_model import is_stable

is_stable(generator.VAR_exog[::-1])
# Out:
# True
